# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# load the data
creditcard = pd.read_csv('data/creditcard.csv')
Fdata = pd.read_csv('data/Fraud_Data.csv')
ipAddress = pd.read_csv('data/ipAddress_to_Country.csv')

# check the first 5 rows
print(creditcard.sample(5))
print(Fdata.sample(5))
print(ipAddress.sample(5))
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 54125    46295.0  1.567927 -1.067331 -0.391116 -1.688535 -0.626932  0.126477
# 17219    28538.0 -1.066599  0.885159  0.591895 -0.015481 -1.642130  0.870663
# 179181  123958.0 -1.393047 -0.246904  1.196514 -2.158916 -1.148388  0.252720
# 211902  138622.0 -0.058761  0.920672 -0.551874 -0.715073  1.098631 -0.395438
# 135153   81127.0 -0.740085  0.991279  1.787030 -0.009073  0.019512 -0.704019
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 54125  -0.912841 -0.044534 -1.761785  ... -0.213939 -0.224770 -0.178866
# 17219   0.195341  0.973274 -0.618152  ...  0.254292  0.493501  0.281727
# 179181  1.789104 -0.137951  0.543405  ... -0.213421 -0.688855  0.281598
# 211902  0.799951  0.048816 -0.135324  ... -0.302203 -0.811173  0.128404
# 135153  0.926740 -0.228092 -0.215658  ... -0.234724 -0.318361  0.076671
#
# ...

# %%
# check for missing values
print(creditcard.isnull().sum())
print(Fdata.isnull().sum())
print(ipAddress.isnull().sum())

# check for duplicates
print(creditcard.duplicated().sum())
print(Fdata.duplicated().sum())
print(ipAddress.duplicated().sum())

# check for data types
print(creditcard.dtypes)
print(Fdata.dtypes)
print(ipAddress.dtypes)
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64
# 1081
# 0
# 0
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# ...
